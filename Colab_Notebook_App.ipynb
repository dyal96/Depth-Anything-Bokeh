# %% [markdown]
# # Depth-Anything-Bokeh (Google Colab)
# Run the cells below to setup and launch the Depth-of-Field (Bokeh) Generator on Google Colab's free GPUs!

# %%
# 1. Clone the repository
# !git clone https://github.com/dyal96/Depth-Anything-Bokeh.git
# %cd Depth-Anything-Bokeh

# %%
# 2. Install dependencies and download checkpoints
# !chmod +x install.sh
# !./install.sh

# %%
# 3. Launch the Gradio App
# A public URL will be generated at the bottom of the output.
# !python app_bokeh.py

# %%
# 4. (No Need to Run Unless There is any issue)
print('Attempting to launch the Gradio app using the recommended script.')
# !chmod +x start_app.sh
# !./start_app.sh
